# %%
import json
import numpy as np

import xpart as xp
import xtrack as xt
import xobjects as xo

num_particles = 10000
nemitt_x = 2.5e-6
nemitt_y = 3e-6

# Load machine model (from pymask)
filename = ('line_and_particle.json')
with open(filename, 'r') as fid:
    input_data = json.load(fid)
line=xt.Line.from_dict(input_data['line'])
line.particle_ref = xp.Particles.from_dict(input_data['particle'])
line.build_tracker()

# Horizontal plane: generate gaussian distribution in normalized coordinates
x_in_sigmas, px_in_sigmas = xp.generate_2D_gaussian(num_particles)

# Vertical plane: generate pencil distribution in normalized coordinates
pencil_cut_sigmas = 6.
pencil_dr_sigmas = 0.7
y_in_sigmas, py_in_sigmas, r_points, theta_points = xp.generate_2D_pencil(
                             num_particles=num_particles,
                             pos_cut_sigmas=pencil_cut_sigmas,
                             dr_sigmas=pencil_dr_sigmas,
                             side='+-')

# Longitudinal plane: generate gaussian distribution matched to bucket 
zeta, delta = xp.generate_longitudinal_coordinates(line=line,
        num_particles=num_particles, distribution='gaussian',
        sigma_z=10e-2)

# Build particles:
#    - scale with given emittances
#    - transform to physical coordinates (using 1-turn matrix)
#    - handle dispersion
#    - center around the closed orbit
particles = line.build_particles(
            zeta=zeta, delta=delta,
            x_norm=x_in_sigmas, px_norm=px_in_sigmas,
            y_norm=y_in_sigmas, py_norm=py_in_sigmas,
            nemitt_x=nemitt_x, nemitt_y=nemitt_y)

# Absolute coordinates can be inspected in particle.x, particles.px, etc.

# Tracking can be done with:
# tracker.track(particles, num_turns=10)

#!end-doc-part

import matplotlib.pyplot as plt
plt.close('all')
fig1 = plt.figure(1, figsize=(6.4, 7))
ax1 = fig1.add_subplot(3,2,1)
ax2 = fig1.add_subplot(3,2,3)
ax3 = fig1.add_subplot(3,2,5)
ax1.plot(x_in_sigmas, px_in_sigmas, '.', markersize=1)
ax1.set_xlabel(r'x [$\sigma$]')
ax1.set_ylabel(r'px [$\sigma$]')
ax1.set_xlim(-7, 7)
ax1.set_ylim(-7, 7)
ax2.plot(y_in_sigmas, py_in_sigmas, '.', markersize=1)
ax2.set_xlabel(r'y [$\sigma$]')
ax2.set_ylabel(r'py [$\sigma$]')
ax2.axvline(x=pencil_cut_sigmas)
ax2.set_xlim(-7, 7)
ax2.set_ylim(-7, 7)
ax3.plot(zeta, delta*1000, '.', markersize=1)
ax3.set_xlabel(r'z [m]')
ax3.set_ylabel(r'$\delta$ [1e-3]')

ax21 = fig1.add_subplot(3,2,2)
ax22 = fig1.add_subplot(3,2,4)
ax23 = fig1.add_subplot(3,2,6)
ax21.plot(particles.x*1000, particles.px, '.', markersize=1)
ax21.set_xlabel(r'x [mm]')
ax21.set_ylabel(r'px [-]')
ax22.plot(particles.y*1000, particles.py, '.', markersize=1)
ax22.set_xlabel(r'y [mm]')
ax22.set_ylabel(r'py [-]')
ax23.plot(particles.zeta, particles.delta*1000, '.', markersize=1)
ax23.set_xlabel(r'z [-]')
ax23.set_ylabel(r'$\delta$ [1e-3]')
fig1.subplots_adjust(bottom=.08, top=.93, hspace=.33,
                     right=.96, wspace=.33)
plt.show()
# Out:
# Done loading line from dict.
# Found suitable prebuilt kernel `default_only_xtrack`.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 33
#      26 y_in_sigmas, py_in_sigmas, r_points, theta_points = xp.generate_2D_pencil(
#      27                              num_particles=num_particles,
#      28                              pos_cut_sigmas=pencil_cut_sigmas,
#      29                              dr_sigmas=pencil_dr_sigmas,
#      30                              side='+-')
#      32 # Longitudinal plane: generate gaussian distribution matched to bucket
# ---> 33 zeta, delta = xp.generate_longitudinal_coordinates(line=line,
#      34         num_particles=num_particles, distribution='gaussian',
#      35         sigma_z=10e-2)
#      37 # Build particles:
#      38 #    - scale with given emittances
#      39 #    - transform to physical coordinates (using 1-turn matrix)
#      40 #    - handle dispersion
#      41 #    - center around the closed orbit
#      42 particles = line.build_particles(
#      43             zeta=zeta, delta=delta,
#      44             x_norm=x_in_sigmas, px_norm=px_in_sigmas,
#      45             y_norm=y_in_sigmas, py_norm=py_in_sigmas,
#      46             nemitt_x=nemitt_x, nemitt_y=nemitt_y)
#
# File c:\Users\bengl\AppData\Local\Programs\Python\Python310\lib\site-packages\xpart\longitudinal\generate_longitudinal.py:147, in generate_longitudinal_coordinates(line, num_particles, distribution, sigma_z, engine, return_matcher, particle_ref, mass0, q0, gamma0, circumference, momentum_compaction_factor, rf_harmonic, rf_voltage, rf_phase, p_increment, tracker, **kwargs)
#     145         particle_ref = line.particle_ref
#     146     assert particle_ref is not None
# --> 147     dct = _characterize_line(line, particle_ref, **kwargs)
#     149 assert particle_ref is not None
#     151 if mass0 is None:
#
# File c:\Users\bengl\AppData\Local\Programs\Python\Python310\lib\site-packages\xpart\longitudinal\generate_longitudinal.py:65, in _characterize_line(line, particle_ref, **kwargs)
#      61 if not found_linear_longitudinal and len(freq_list) == 0:
#      62     raise ValueError('No longitudinal focusing found in the line. '
#      63                      'Cannot generate matched longitudinal coordinates.')
# ---> 65 tw = line.twiss(
#      66     particle_ref=particle_ref, **kwargs)
#      68 dct={}
#      69 dct['T_rev'] = T_rev
#
# File c:\Users\bengl\AppData\Local\Programs\Python\Python310\lib\site-packages\xtrack\line.py:955, in Line.twiss(self, particle_ref, method, particle_on_co, R_matrix, W_matrix, delta0, zeta0, r_sigma, nemitt_x, nemitt_y, delta_disp, delta_chrom, zeta_disp, particle_co_guess, steps_r_matrix, co_search_settings, at_elements, at_s, continue_on_closed_orbit_error, freeze_longitudinal, freeze_energy, values_at_element_exit, radiation_method, eneloss_and_damping, ele_start, ele_stop, twiss_init, skip_global_quantities, matrix_responsiveness_tol, matrix_stability_tol, symplectify, reverse, use_full_inverse, strengths, hide_thin_groups, group_compound_elements, only_twiss_init, _continue_if_lost, _keep_tracking_data, _keep_initial_particles, _initial_particles, _ebe_monitor)
#     952         tw_kwargs[kk] = vv
#     954 tw_kwargs.pop('self')
# --> 955 return twiss_line(self, **tw_kwargs)
#
# File c:\Users\bengl\AppData\Local\Programs\Python\Python310\lib\site-packages\xtrack\twiss.py:394, in twiss_line(line, particle_ref, method, particle_on_co, R_matrix, W_matrix, delta0, zeta0, r_sigma, nemitt_x, nemitt_y, delta_disp, delta_chrom, zeta_disp, particle_co_guess, steps_r_matrix, co_search_settings, at_elements, at_s, continue_on_closed_orbit_error, freeze_longitudinal, freeze_energy, values_at_element_exit, radiation_method, eneloss_and_damping, ele_start, ele_stop, twiss_init, skip_global_quantities, matrix_responsiveness_tol, matrix_stability_tol, symplectify, reverse, use_full_inverse, strengths, hide_thin_groups, group_compound_elements, only_twiss_init, _continue_if_lost, _keep_tracking_data, _keep_initial_particles, _initial_particles, _ebe_monitor)
#     390 if twiss_init is None or twiss_init=='periodic':
#     391     # Periodic mode
#     392     periodic = True
# --> 394     twiss_init, R_matrix = _find_periodic_solution(
#     395         line=line, particle_on_co=particle_on_co,
#     396         particle_ref=particle_ref, method=method,
#     397         co_search_settings=co_search_settings,
#     398         continue_on_closed_orbit_error=continue_on_closed_orbit_error,
#     399         delta0=delta0, zeta0=zeta0, steps_r_matrix=steps_r_matrix,
#     400         W_matrix=W_matrix, R_matrix=R_matrix,
#     401         particle_co_guess=particle_co_guess,
#     402         delta_disp=delta_disp, symplectify=symplectify,
#     403         matrix_responsiveness_tol=matrix_responsiveness_tol,
#     404         matrix_stability_tol=matrix_stability_tol,
#     405         ele_start=ele_start, ele_stop=ele_stop)
#     406 else:
#     407     # force
#     408     skip_global_quantities = True
#
# File c:\Users\bengl\AppData\Local\Programs\Python\Python310\lib\site-packages\xtrack\twiss.py:1059, in _find_periodic_solution(line, particle_on_co, particle_ref, method, co_search_settings, continue_on_closed_orbit_error, delta0, zeta0, steps_r_matrix, W_matrix, R_matrix, particle_co_guess, delta_disp, symplectify, matrix_responsiveness_tol, matrix_stability_tol, ele_start, ele_stop)
#    1052     else:
#    1053         RR = line.compute_one_turn_matrix_finite_differences(
#    1054                                     steps_r_matrix=steps_r_matrix,
#    1055                                     particle_on_co=part_on_co,
#    1056                                     ele_start=ele_start,
#    1057                                     ele_stop=ele_stop)
# -> 1059     W, _, _ = lnf.compute_linear_normal_form(
#    1060                             RR, only_4d_block=(method == '4d'),
#    1061                             symplectify=symplectify,
#    1062                             responsiveness_tol=matrix_responsiveness_tol,
#    1063                             stability_tol=matrix_stability_tol)
#    1065 if method == '4d' and W_matrix is None: # the matrix was not provided by the user
#    1066
#    1067     # Compute dispersion (MAD-8 manual eq. 6.13, but I needed to flip the sign ?!)
#    1068     A_disp = RR[:4, :4]
#
# File c:\Users\bengl\AppData\Local\Programs\Python\Python310\lib\site-packages\xtrack\linear_normal_form.py:112, in compute_linear_normal_form(M, symplectify, only_4d_block, responsiveness_tol, stability_tol)
#     110     mask_non_zero[ii] = False
#     111     if np.sum(mask_non_zero)<1:
# --> 112         raise ValueError(
#     113             'Invalid one-turn map: No coordinates respond to variations of '
#     114             + 'x px y py zeta delta'.split()[ii])
#     116 if symplectify:
#     117     M = healy_symplectify(M)
#
# ValueError: Invalid one-turn map: No coordinates respond to variations of x
