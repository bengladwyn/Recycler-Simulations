# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# how to read IPM data

# %%
turn400V = np.load('6turns0_V.npy')
turn400H = np.load('6turns0_H.npy')

# %%
mcp_width = 500e-6

# %%
print (f'there are {turn400V.shape[0]} turn worth of data. Each IPM has {turn400V.shape[0]} micro channel plates and each plate has a width of {mcp_width}')
# Out:
# there are 1024 turn worth of data. Each IPM has 1024 micro channel plates and each plate has a width of 0.0005

# %%
plt.plot(turn400H[100])
plt.xlabel('mcp')
plt.ylabel('counts (a.u)')
# Out:
# Text(0, 0.5, 'counts (a.u)')
